# %% [markdown]
# ##### <center> MINISTERE DE L’ENSEIGNEMENT SUPERIEUR  ET DE LA RECHERCHE SCIENTIFIQUE <br/> UNIVERSITE DE SOUSSE </center>
#
#
#
# ### <center>Institut Supérieur d’Informatique et de Technique de Communication </center>           <img src="isitcom.png">
# ### <center>المعهد العالي للإعلامية و تقنيات الاتصال بحمام سوسة</center>
#
#
#
# ## <center> <div style="background-color:lavender;color:steelBlue;padding:1%;"><font style="font-family:italic;" size="12" >Analyse numérique</div>
#
#
#
# # <center> <div style="text-decoration: underline;"><font size="5" >TP1</div>
#
#
#
#
# ###  <center> Réalisé par : <br><br> Firas Fékih  <br><br> 2DNI1  <center> <hr>
#
#
#
# #### <center> Année Universitaire 2020 – 2021 <center>
# <hr>

# %% [markdown]
# # EXERCICE 1
# > On considère le polynôme $p(x) = (x - 1)^6$. .
# >En développant on peut écrire ce même polynôme sous la forme  $𝑓(𝑥)=𝑥6−6𝑥5+15𝑥4−20𝑥3+15𝑥2−6𝑥+1$.
# >  1) Avec Matlab évaluer  $𝑝(𝑥)$  et  $𝑓(𝑥)  pour  𝑥  allant de  .998  à  1.002  en choisissant des pas de  .0001 .
# <br>
# > 2) Faire un graphique de  𝑓(𝑥)  et  𝑝(𝑥) .

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# > # Réponse
# > <BR> Dans cette partie on va choisir un reel x qui appartient a l'intervalle [0.998,1.002]
#    > <br> en choissisant un pas de 0.001

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0.998, 1.002, 0.0001)

# %% [markdown]
# >Puis on va declarer deux fonctions p(x) et f(x) en utilisant la fonction lambda (qu'est expliquée dans le fichier basics ).
# > <br> ces deux fonctions sont vraiment trés **proches** dans un itervalle qu'est tres etroit
# > <br>la fonction f est fréquemment est egale à g (s'annule)  .
# > <br>et c'est déja notre **principe!**  donc on peut dterminer des solution d'une fonction difficile  a partir d'une fonction >plus simple

# %%
p = lambda x:(x-1)**6
fig = plt.figure(1, figsize=(15, 5))
plt.plot(x,p(x))
f = lambda x: x**6 - 6*x**5 + 15*x**4 - 20*x**3 + 15*x**2 - 6*x + 1
fig = plt.figure(1, figsize=(15, 10))
plt.plot(x,f(x))
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('solution dans[0.998:0.0001:1.002] ')
plt.legend(('p(x)', 'f(x)'))
plt.grid(True)
plt.show()

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# </div><h1><center>Méthode de dichotomie</center></h1>
# <br>&nbsp;&nbsp;La <span class=rougedico>méthode de dichotomie</span> est une méthode pour trouver une solution approchée
# à une équation $f(x)=0$. Précisément, supposons que la fonction $f$ est continue sur l'intervalle $[a,b]$,
# avec $f(a)\leq 0$ et $f(b)\geq 0$. On sait donc qu'il existe au moins un réel $c$ dans l'intervalle $[a,b]$
# tel que $f( c)=0$.</p>
# &nbsp;&nbsp;L'idée est alors d'évaluer ce que vaut $f$ au milieu de $[a,b]$, et de distinguer les deux cas suivants :
# <div class=liste>
# <ul>
# <li>si $f\left(\frac{a+b}2\right)\leq 0$, alors on sait qu'on a une racine dans l'intervalle $\left[\frac{a+b}2,b\right]$.
# <li>sinon, $f\left(\frac{a+b}2\right)> 0$ et on sait qu'on a une racine dans l'intervalle $\left[a,\frac{a+b}2\right]$.
# </ul>
# </div>
# Ainsi, dans les deux cas, on a trouvé un intervalle de longueur moitié dans lequel est située une racine de l'équation
# $f(x)=0$. On recommence alors avec cet intervalle, et ainsi de suite jusqu'à ce qu'on trouve une approximation
# qui nous convienne.</p>
# &nbsp;&nbsp;Formellement, on définit les suites $(a_n)$ et $(b_n)$ en posant
# <div class=liste>
# <ul>
# <li>$a_0=a$ et $b_0=b$.
# <li>si $f\left(\frac{a_n+b_n}2\right)\leq 0$, alors $a_{n+1}=\frac{a_n+b_n}2$ et $b_{n+1}=b_n$.
# <li>sinon, $a_{n+1}=a_n$ et $b_{n+1}=\frac{a_n+b_n}2$.
# </ul></div>
# On a toujours une solution à l'équation $f(x)=0$ dans l'intervalle $[a_n,b_n]$, qui est de longueur
# $(b_n-a_n)/2^n$.</p>
# &nbsp;&nbsp;Il existe des méthodes plus efficaces que la dichotomie pour
#  rechercher pratiquement les solutions d'une équation f(x)=0.
#  La plus connue est sans doute la méthode
#  de Newton.</p>

# %% [markdown]
# # Exercice 2

# %% [markdown]
# >On considère l'équation : $$ f(x)=x^3+x^2-3x-3=0$$
# >1) Dessiner la courbe de $f$ dans l'intervalle $[-2;2]$, puis trouver des intervalles convenables pour appliquer la méthode de bisection.
# >
# >2) Utiliser un programme `dicho.m` qui permettra de trouver les solutions de l'équation $f(x)=0$ avec $eps=0.001$.
# >
# >3) Modifier le programme `dicho.m` pour qu'il donne le nombre d'itération nécessaire pour avoir la solution à $eps$ près.

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------
# ## Réponse
# 1)

# %%
import matplotlib.pyplot as plt
from numpy import linspace
def f(x):
    return x**3+x**2-3*x-3
#Représentation graphique:
T=linspace(-2,2,41)
plt.title("solution dans [-2:2] ");
plt.xlabel("x")
plt.ylabel ("f(x)")
plt.grid(True)
plt.plot(T,f(T))
plt.show()
def dicho(f,a,b,tol):
    m=(a+b)/2
    err=abs(b-a)
    while err>tol :
        if f(m)==0 :
            break
        if f(a)*f(m)<0 :
            b=m
        else: a=m
        m=(a+b)/2
        err=abs(b-a)
    return m
print(dicho(g,-2,2,0.001))
# Out:
# 1.73193359375

# %% [markdown]
# 2)

# %%
def dichow(f,a,b,tol):
    m=(a+b)/2
    err=abs(b-a)
    i=0
    while err>tol :
        if f(m)==0 :
            break
   
        if f(a)*f(m)<0 :
            b=m
        else: a=m
    
        m=(a+b)/2
        err=abs(b-a)
        i=i+1
    return (m,i)

print(dichow(g,-2,-1.5,0.0001))
# Out:
# (-1.732025146484375, 13)

# %% [markdown]
# 3)

# %%
import matplotlib.pyplot as plt
from numpy import linspace
import numpy as np 

t=linspace(1.7,1.75,100)
plt.subplot(2,2,1)
plt.plot(t,f(t),'r')

t=linspace(1.2,1.4,100)
plt.subplot(2,2,2)
plt.plot(t,f(t),'g')

t=linspace(1.35,1.4,100)
plt.subplot(2,2,3)
plt.plot(t,f(t),'y')

t=linspace(1.365,1.367,100)
plt.subplot(2,2,4)
plt.plot(t,f(t),'m')
plt.show()

# %%
import numpy as np
np.floor(2.3)
np.ceil(2.3)
# Out:
# 3.0

# %%
import numpy as np
a=-1.5
b=-0.5
p=8 # précision à 10 ^-8 prés
print(dichow(f,a,b,(10**(-p))))
(-1.0, 0)
# Out:
# (-0.5000000037252903, 27)
# (-1.0, 0)

# %%
interval=[[-2,-1.5],[-1.5,-0.5],[1.5,2]]
for u in interval:
    print(dichow(f,u[0],u[1],10**(-3)))
# Out:
# (-1.73193359375, 9)
# (-1.0, 0)
# (1.73193359375, 9)

# %% [markdown]
# => le nombre d'iteration c'est 9 !

# %% [markdown]
# Le nombre d'itération N nécéssaire à la méthode de la dichotomie pour trouver $\alpha$ à $10^{-p}$ prés
#
# $$N \geq E\left(\dfrac{\ln(b-a)+p\ln(10)}{\ln(2)}\right)+1$$

# %% [markdown]
# # EXERCICE 3:
# >On considère l'équation : $$ f(x)=x^3+4x^2-10=0$$
# >1) Dessiner la courbe de $f$ dans l'intervalle $[1;2]$, puis trouver une valeur approché de la solution à 0.001 près (En >utilisant la fonction zoom du graphique).
# >
# >2) Vérifier que cette équation est équivalente aux 3 schéma du point fixe suivant:
# >
# >a) $g_1(x)=\frac{1}{2}\sqrt{10-x^3}=x$.
# >
# >b) $g_2(x)=\sqrt{\displaystyle\frac{10}{4+x}}=x$.
# >
# >c) $g_3(x)=x-x^3-4x^2+10=x$.
# >
# >3) Ecrire puis appliquer  une fonction Matlab que l'on appellera  `pointfixe.m` aux trois schémas précédents en prenant >`x0=1.5;eps=0.001`.
# >
# >4) Quelle est la fonction (parmi $g_1, g_2$ et $g_3$) qui donne la convergence la plus rapide?
# >

# %%
import matplotlib.pyplot as plt
from numpy import linspace
def h(x):
    return x**3+4*x**2-10

# %%
# Représentation graphique:
t=np.linspace(1,2,100)
plt.subplot(2,2,1)
plt.plot(t,f(t),'r')
plt.grid(True)
##########################
t=np.linspace(1.2,1.4,100)
plt.subplot(2,2,2)
plt.plot(t,f(t),'y')
plt.grid(True)
###########################
t=np.linspace(1.35,1.4,100)
plt.subplot(2,2,3)
plt.plot(t,f(t),'m')
plt.grid(True)
##############################
t=np.linspace(1.365,1.367,100)
plt.subplot(2,2,4)
plt.plot(t,f(t),'g')
plt.grid(True)

# %%
from sympy import *
import numpy as np
x, y, z = symbols('x y z')
init_printing(use_unicode=True)
def g1(x):
 return 1/2*sqrt(10-x**3)
g1=lambda x: 1/2*sqrt(10-x**3)
dg1=lambdify(x,diff(g1(x),x,1))
dg1(1.365)
# Out:
# -0.5117446282927461

# %% [markdown]
# Que pouvez vous conclure à propos des convergences de g1:
# Puisque la valeur de g1 est négatife et la valeur absolu de g1 |g1(x)| est inférieur à 1 donc la méthode de point fixe converge totalemen, c'est à dire, il exixteun locale I dans l'intervale [1,2].

# %%
f=lambda x:  x**3+4*x**2-10 # la fonction f
g1=lambda x: 1/2*sqrt(10-x**3)
g2=lambda x: sqrt(10/(x+4))
g3=lambda x: x-x**3-4*x**2 + 10


def ptfixe(g,x0,eps,nmax):
    pass





    print('pas de convergence avec le nombre d''iteration indique')

# %%
print(pointfixe(g1,1.5,0.001,50))
# Out:
# None

# %% [markdown]
# ### quelle est la fonction qui donne la convergence la plus rapide ??
#
# Donner le nombre d'itération pour chaque méthode convergent e
# + $g_2$ donne le resultat en ? itérations
# + $g_1$ donne le resultat en ?
# + $g_3$ est - elle convergente?

# %% [markdown]
# # EXERCICE 4:

# %%
def newton(f,fprime,a,eps):
    x1=a
    x2=x1-f(x1)/fprime(x1)
    while abs(x1-x2)>eps :
        x1=x2
        x2=x1-f(x1)/fprime(x1)
    return x2

# %%
import math
from sympy import *
from sympy.abc import x

f=lambda x: math.exp(-x)-x
fprime=lambda x: -math.exp(-x)-1
newton(f,fprime,0,0.001)
# Out:
# 0.5671431650348622

# %% [markdown]
# <font size="4">  la méthode de Newton est la méthode la plus rapide avec un ordre de convergence,au moins=2
